# %% [markdown]
# # K Means Clustering
# K Means Clustering is an unsupervised learning algorithm that tries to cluster data based on their similarity. Unsupervised learning means that there is no outcome to be predicted, and the algorithm just tries to find patterns in the data. In k means clustering, we have the specify the number of clusters we want the data to be grouped into. The algorithm randomly assigns each observation to a cluster, and finds the centroid of each cluster.
#
#
# Then, the algorithm iterates through two steps:
# + Reassign data points to the cluster whose centroid is closest.
# + Calculate new centroid of each cluster.
#
# These two steps are repeated till the within cluster variation cannot be reduced any further. The within cluster variation is calculated as the sum of the euclidean distance between the data points and their respective cluster centroids.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Import Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# <hr>

# %% [markdown]
# ## Create some Data

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.8)

# %% [markdown]
# <hr>

# %% [markdown]
# ## Vizualize Data

# %%
plt.scatter(data[0][:,0],data[0][:,1], c=data[1], cmap='rainbow')

# %% [markdown]
# <hr>

# %% [markdown]
# ## Creating the Clusters

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(n_clusters=4)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 5.02807108,  3.49374122],
#        [-8.39525386,  2.79055626],
#        [-5.53573756, -8.33733623],
#        [-0.88619491,  4.63993196]])

# %%
kmeans.labels_
# Out:
# array([0, 2, 1, 0, 0, 3, 0, 2, 3, 0, 2, 1, 0, 2, 1, 3, 3, 2, 0, 1, 1, 2,
#        0, 2, 0, 3, 2, 2, 2, 0, 0, 2, 3, 1, 3, 3, 2, 1, 0, 3, 0, 1, 2, 3,
#        0, 2, 2, 1, 2, 1, 2, 1, 0, 3, 1, 1, 1, 0, 2, 3, 3, 2, 1, 3, 1, 3,
#        2, 3, 3, 0, 0, 1, 1, 0, 0, 3, 3, 0, 0, 3, 0, 3, 3, 0, 0, 1, 1, 1,
#        1, 2, 2, 1, 2, 2, 2, 2, 0, 3, 3, 2, 1, 0, 0, 1, 3, 3, 1, 2, 1, 0,
#        3, 2, 2, 3, 1, 2, 3, 2, 2, 3, 2, 2, 1, 3, 2, 0, 1, 3, 0, 0, 2, 3,
#        3, 3, 1, 0, 2, 2, 1, 3, 3, 2, 2, 1, 1, 1, 1, 1, 0, 3, 1, 2, 3, 2,
#        1, 1, 0, 0, 1, 3, 2, 1, 0, 2, 0, 0, 1, 0, 1, 3, 1, 1, 1, 0, 2, 1,
#        2, 0, 3, 0, 0, 0, 1, 2, 3, 0, 1, 0, 0, 0, 3, 3, 3, 2, 0, 3, 0, 2,
#        0, 3])

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %% [markdown]
# <hr>
